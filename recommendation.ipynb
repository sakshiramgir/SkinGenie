# %%
import pandas as pd

# %%
df = pd.read_csv("skincare_product.csv")

# %%
df.columns
# Out:
# Index(['product_href', 'product_name', 'product_type', 'brand',
#        'notable_effects', 'skintype', 'price', 'description', 'picture_src'],
#       dtype='object')

# %%
df
# Out:
#                                            product_href  \
# 0     https://www.beautyhaul.com/product/detail/bubb...
# 1     https://www.sociolla.com/face-wash/62452-ph-ba...
# 2     https://www.sociolla.com/toner/15871-licorice-...
# 3     https://www.beautyhaul.com/product/detail/aqua...
# 4     https://www.sociolla.com/essence/38023-licoric...
# ...                                                 ...
# 1219  https://www.sociolla.com/face-cream-lotion/263...
# 1220  https://shopee.co.id/YOU-The-Radiance-White-Pu...
# 1221  https://shopee.co.id/YOU-Basic-Skin-Care-Simpl...
# 1222  https://shopee.co.id/YOU-Dazzling-Glow-Up-Faci...
# 1223  https://shopee.co.id/YOU-Golden-Age-Deep-Clean...
#
#                                            product_name product_type  \
# 0              ACWELL Bubble Free PH Balancing Cleanser    Face Wash
# 1           ACWELL pH Balancing Soothing Cleansing Foam    Face Wash
# 2         Acwell Licorice pH Balancing Cleansing Toner         Toner
# 3                       ACWELL Aquaseal Soothing Tonic         Toner
# 4                    Licorice pH Balancing Essence Mist        Toner
# ...                                                 ...          ...
# 1219                    Whitelab Brightening Day Cream   Moisturizer
# 1220       YOU The Radiance White Purifying Facial Foam    Face Wash
# 1221  YOU Basic Skin Care Simply Fresh and Bright Fa...    Face Wash
# 1222                   YOU Dazzling Glow Up Facial Foam    Face Wash
# 1223          YOU Golden Age Deep Cleansing Facial Wash    Face Wash
#
#            brand                                notable_effects  \
# 0        ACWELL   Acne-Free, Pore-Care, Brightening, Anti-Aging
# 1        ACWELL                             Soothing, Balancing
# 2        ACWELL                             Soothing, Balancing
# 3        ACWELL   Acne-Free, Pore-Care, Brightening, Anti-Aging
# 4        ACWELL                           Brightening, Soothing
# ...          ...                                            ...
# 1219  WHITELAB                       Brightening, UV-Protection
# 1220         YOU                       Moisturizing, Refreshing
# 1221         YOU                          Refreshing, Acne-Free
# 1222         YOU                        Hydrating, Moisturizing
# 1223         YOU             Pore-Care, Brightening, Anti-Aging
#
#                                        skintype       price  \
# 0                                          Oily  Rp 209.000
# 1                      Normal, Dry, Combination  Rp 181.800
# 2     Normal, Dry, Oily, Combination, Sensitive  Rp 149.000
# 3                                          Oily  Rp 290.000
# 4                                   Normal, Dry  Rp 194.650
# ...                                         ...         ...
# 1219  Normal, Dry, Oily, Combination, Sensitive   Rp 61.950
# 1220               Normal, Dry, Oily, Sensitive   Rp 52.000
# 1221               Normal, Dry, Oily, Sensitive  Rp 25.000
# 1222               Normal, Dry, Oily, Sensitive   Rp 35.000
# 1223               Normal, Dry, Oily, Sensitive   Rp 55.000
#
#                                             description  \
# 0     Mengangkat kotoran dan menghapus makeup dalam ...
# 1     Membersihkan dan menenangkan kulit sensitif de...
# 2     Mengangkat sisa kotoran, debu, dan make up sek...
# 3     Pre-essence yang diformulasikan dengan ekstrak...
# 4     Essens mist dengan kelembapan tinggi yang memb...
# ...                                                 ...
# 1219  Whitelab Brightening Day Cream Fungsi: - Memba...
# 1220  YOU The Radiance White Purifying Facial Foam [...
# 1221  YOU Simply Fresh Honey and lemon Facial Wash S...
# 1222  A mild facial foam with Rice Extract, Tranexam...
# 1223  Golden Age Deep Cleansing Facial Wash diformul...
#
#                                             picture_src
# 0     https://www.beautyhaul.com/assets/uploads/prod...
# 1     https://images.soco.id/8f08ced0-344d-41f4-a15e...
# 2     https://www.soco.id/cdn-cgi/image/w=73,format=...
# 3     https://www.beautyhaul.com/assets/uploads/prod...
# 4     https://www.sociolla.com/cdn-cgi/image/w=425,f...
# ...                                                 ...
# 1219  https://www.soco.id/cdn-cgi/image/w=73,format=...
# 1220  https://cdn.istyle.im/images/product/web/27/61...
# 1221  https://images.tokopedia.net/img/cache/700/pro...
# 1222  https://images.tokopedia.net/img/cache/700/Vqb...
# 1223  http://image.femaledaily.com/dyn/640/images/pr...
#
# [1224 rows x 9 columns]

# %%
df.isnull()
# Out:
#       product_href  product_name  product_type  brand  notable_effects  \
# 0            False         False         False  False            False
# 1            False         False         False  False            False
# 2            False         False         False  False            False
# 3            False         False         False  False            False
# 4            False         False         False  False            False
# ...            ...           ...           ...    ...              ...
# 1219         False         False         False  False            False
# 1220         False         False         False  False            False
# 1221         False         False         False  False            False
# 1222         False         False         False  False            False
# 1223         False         False         False  False            False
#
#       skintype  price  description  picture_src
# 0        False  False        False        False
# 1        False  False        False        False
# 2        False  False        False        False
# 3        False  False        False        False
# 4        False  False        False        False
# ...        ...    ...          ...          ...
# 1219     False  False        False        False
# 1220     False  False        False        False
# 1221     False  False        False        False
# 1222     False  False        False        False
# 1223     False  False        False        False
#
# [1224 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# product_href       0
# product_name       0
# product_type       0
# brand              0
# notable_effects    0
# skintype           0
# price              0
# description        0
# picture_src        0
# dtype: int64

# %%
df['product_type'].unique()
# Out:
# array(['Face Wash', 'Toner', 'Serum', 'Moisturizer', 'Sunscreen'],
#       dtype=object)

# %%
df['product_name'].unique()
# Out:
# array(['ACWELL Bubble Free PH Balancing Cleanser',
#        'ACWELL pH Balancing Soothing Cleansing Foam',
#        'Acwell Licorice pH Balancing Cleansing Toner ', ...,
#        'YOU Basic Skin Care Simply Fresh and Bright Facial Wash',
#        'YOU Dazzling Glow Up Facial Foam',
#        'YOU Golden Age Deep Cleansing Facial Wash'], dtype=object)

# %%
df['product_type'].unique()
# Out:
# array(['Face Wash', 'Toner', 'Serum', 'Moisturizer', 'Sunscreen'],
#       dtype=object)

# %%
df['skintype'].unique()
# Out:
# array(['Oily', 'Normal, Dry, Combination',
#        'Normal, Dry, Oily, Combination, Sensitive', 'Normal, Dry',
#        'Normal, Dry, Oily, Combination', 'Dry, Oily, Sensitive',
#        'Normal, Combination', 'Dry, Sensitive', 'Sensitive', 'Dry',
#        'Oily, Combination, Sensitive', 'Oily, Sensitive',
#        'Oily, Combination', 'Normal, Dry, Oily, Sensitive',
#        'Normal, Oily'], dtype=object)

# %%
df['notable_effects'].unique()
# Out:
# array(['Acne-Free, Pore-Care, Brightening, Anti-Aging',
#        'Soothing, Balancing', 'Brightening, Soothing',
#        'Moisturizing, Brightening, Anti-Aging',
#        'Moisturizing, Brightening', 'Hydrating, Balancing, Moisturizing',
#        'Pore-Care, Brightening, Anti-Aging', 'Anti-Aging',
#        'Brightening, Anti-Aging, UV-Protection',
#        'Anti-Aging, UV-Protection', 'Balancing, Oil-Control, Pore-Care',
#        'Hydrating, Moisturizing', 'Hydrating, Soothing',
#        'UV-Protection, No-Whitecast', 'Skin-Barrier, UV-Protection',
#        'Moisturizing, Pore-Care', 'Hydrating, Refreshing',
#        'Hydrating, Pore-Care', 'Moisturizing, Refreshing, Oil-Control',
#        'Moisturizing, UV-Protection', 'Hydrating, UV-Protection',
#        'Acne-Free, Oil-Control, Anti-Aging', 'Hydrating, Pore-Care ',
#        'Moisturizing', 'Moisturizing, Refreshing',
#        'Moisturizing, Brightening, Black-Spot',
#        'Soothing, Brightening, Black-Spot',
#        'Soothing, Balancing, Brightening',
#        'Acne-Free, Oil-Control, Pore-Care',
#        'Moisturizing, Anti-Aging, Skin-Barrier', 'Soothing, Brightening',
#        'Hydrating, Anti-Aging, Skin-Barrier', 'Brightening, Anti-Aging',
#        'Brightening, Black-Spot, Anti-Aging, Skin-Barrier',
#        'Acne-Free, Oil-Control, Brightening, Skin-Barrier',
#        'Soothing, UV-Protection',
#        'Hydrating, Acne-Free, Brightening, Black-Spot',
#        'Acne-Free, Pore-Care, Anti-Aging',
#        'Soothing, Acne-Free, Oil-Control', 'Soothing, Moisturizing',
#        'Moisturizing, Brightening, Black-Spot, Anti-Aging',
#        'UV-Protection', 'Moisturizing, Acne-Free',
#        'Hydrating, Moisturizing, Refreshing',
#        'Brightening, UV-Protection',
#        'Hydrating, Moisturizing, UV-Protection',
#        'Hydrating, Balancing, Skin-Barrier',
#        'Acne-Free, Brightening, Anti-Aging', 'Acne-Free, Anti-Aging',
#        'Moisturizing, Brightening, Skin-Barrier',
#        'Soothing, Moisturizing, Brightening, Black-Spot',
#        'Soothing, Acne-Free, Pore-Care',
#        'Acne-Free, Oil-Control, Black-Spot', 'Refreshing, Pore-Care',
#        'Soothing, Refreshing', 'Acne-Free, Pore-Care, Black-Spot',
#        'Acne-Free, Skin-Barrier', 'Oil-Control, Pore-Care, Skin-Barrier',
#        'Moisturizing, UV-Protection, No-Whitecast',
#        'Pore-Care, Skin-Barrier, UV-Protection', 'Soothing, Skin-Barrier',
#        'Brightening, Skin-Barrier', 'Hydrating, Soothing, Acne-Free',
#        'Hydrating, Pore-Care, Brightening',
#        'Soothing, Balancing, Pore-Care',
#        'Pore-Care,  Brightening, Anti-Aging',
#        'Acne-Free, Brightening, Black-Spot',
#        'Moisturizing, Brightening, UV-Protection',
#        'Acne-Free, Oil-Control', 'Acne-Free, UV-Protection',
#        'Moisturizing, Acne-Free, Oil-Control',
#        'Balancing, Acne-Free, Pore-Care',
#        'Soothing, Moisturizing, UV-Protection',
#        'Balancing, Moisturizing, Anti-Aging',
#        'Balancing, Pore-Care, Brightening', 'Oil-Control, Pore-Care',
#        'Pore-Care, Brightening', 'Acne-Free, Pore-Care, Skin-Barrier',
#        'Moisturizing, Acne-Free, Skin-Barrier',
#        'Acne-Free, Oil-Control, Skin-Barrier',
#        'Balancing, Moisturizing, Oil-Control\n',
#        'Acne-Free, Brightening, Pore-Care', 'Acne-Free, Brightening',
#        'Brightening, Black-Spot, Anti-Aging',
#        'Soothing, Moisturizing, Anti-Aging',
#        'Hydrating, Brightening, Black-Spot',
#        'Hydrating, Balancing, Oil-Control, Brightening',
#        'Hydrating, Oil-Control', 'Acne-Free, Oil-control, Pore-Care',
#        'Hydrating, Pore-Care, Skin-Barrier',
#        'Brightening, UV-Protection ',
#        'Acne-Free, Moisturizing, Oil-Control, Pore-Care',
#        'Hydrating, Moisturizing, Pore-Care',
#        'Moisturizing, Oil-Control, Pore-Care',
#        'Moisturizing, Acne-Free, Anti-Aging',
#        'Moisturizing, Skin-Barrier', 'Pore-Care, Skin-Barrier ',
#        'Anti-Aging, Skin-Barrier, UV-Protection, No-Whitecast',
#        'Soothing, Moisturizing, Skin-Barrier',
#        'Soothing, Moisturizing, Black-Spot',
#        'Refreshing, Moisturizing, Brightening, Skin-Barrier',
#        'Moisturizing, Acne-Free, Black-Spot',
#        'Soothing, Acne-Free, Moisturizing',
#        'Soothing, Brightening, Acne-Spot',
#        'Hydrating, Moisturizing, Acne-Free, Pore-Care', 'Moisturizing ',
#        'Hydrating, Acne-Free, Oil-Control',
#        'Hydrating, Moisturizing, Acne-Free, Oil-Control, Pore-Care',
#        'Acne-Free, Oil-Control, Pore-Care, Brightening',
#        'Hydrating, Brightening', 'Moisturizing, Oil-Control',
#        'Brightening, Black-Spot, UV-Protection',
#        'Moisturizing, Anti-Aging', 'Hydrating, Soothing, Brightening',
#        'Soothing, Balancing, Acne-Free',
#        'Hydrating, Oil-Control, Pore-Care',
#        'Soothing, Acne-Free, Skin-Barrier',
#        'Hydrating, Moisturizing, Skin-Barrier',
#        'Hydrating, Moisturizing, Anti-Aging',
#        'Soothing, Moisturizing, Acne-Free',
#        'Soothing, Brightening, UV-Protection',
#        'Acne-Free, Oil-Control, Black-Spot, Skin-Barrier',
#        'Soothing, Refreshing, Oil-Control', 'Pore-Care, Skin-Barrier',
#        'Hydrating, Pore-Care, Oil-Control', 'Balancing, Pore-Care',
#        'Pore-Care, Anti-Aging', 'Hydrating, Balancing',
#        'Balancing, Moisturizing', 'Soothing, Acne-Free',
#        'UV-Protection, No-Whitecast ',
#        'Pore-Care, UV-Protection, No-Whitecast ',
#        'Refreshing, Skin-Barrier', 'Soothing, Balancing, Oil-Control',
#        'Hydrating, Soothing ', 'Brightening, Black-Spot, Skin-Barrier',
#        'Soothing, Anti-Aging, Skin-Barrier',
#        'Balancing, Brightening, Skin-Barrier',
#        'Pore-Care, UV-Protection, No-Whitecast', 'Pore-Care, Black-Spot',
#        'Soothing, Oil-Control, Pore-Care', 'Refreshing, Oil-Control',
#        'Hydrating, Acne-Free, Pore-Care',
#        'Hydrating, Soothing, Moisturizing',
#        'Moisturizing, Acne-Free, Brightening',
#        'Hydrating, Moisturizing, Oil-Control',
#        'Moisturizing, Pore-Care, Brightening', 'Acne-Free, Pore-Care',
#        'Hydrating, Acne-Free, Brightening ',
#        'Soothing, Acne-Free, Oil-Control, Pore-Care',
#        'Refreshing, Acne-Free'], dtype=object)

# %%
def recommend_routines(skin_type, concerns):
    # Ensure case consistency by converting both input and dataset values to lowercase
    skin_type = skin_type.strip().lower()
    concerns = [concern.strip().lower() for concern in concerns.split(",")]
    
    # Standardize dataset values to lowercase for comparison
    df['skintype'] = df['skintype'].str.lower()
    df['notable_effects'] = df['notable_effects'].str.lower()
    df['product_type'] = df['product_type'].str.lower()

    # Filter dataset based on skin type
    filtered_df = df[df['skintype'].str.contains(skin_type, na=False)]
    if filtered_df.empty:
        print("No products found for the given skin type.")
        return None

    # Further filter dataset based on concerns
    filtered_df = filtered_df[filtered_df['notable_effects'].apply(
        lambda x: any(concern in x for concern in concerns))]
    if filtered_df.empty:
        print("No products found matching the specified concerns.")
        return None

    # Get common products for both routines
    facewash = filtered_df[filtered_df['product_type'] == 'face wash']['product_name'].head(1).tolist()
    moisturizer = filtered_df[filtered_df['product_type'] == 'moisturizer']['product_name'].head(1).tolist()

    # Get morning-specific products
    morning_toner = filtered_df[filtered_df['product_type'] == 'toner']['product_name'].head(1).tolist()
    morning_serum = filtered_df[filtered_df['product_type'] == 'serum']['product_name'].head(1).tolist()
    sunscreen = filtered_df[filtered_df['product_type'] == 'sunscreen']['product_name'].head(1).tolist()

    # Get evening-specific products
    evening_toner = filtered_df[filtered_df['product_type'] == 'toner']['product_name'].iloc[1:2].tolist()
    evening_serum = filtered_df[filtered_df['product_type'] == 'serum']['product_name'].iloc[1:2].tolist()

    # Create morning and evening routines
    morning_routine = {
        "facewash": facewash,
        "toner": morning_toner,
        "serum": morning_serum,
        "moisturizer": moisturizer,
        "sunscreen": sunscreen,
    }

    evening_routine = {
        "facewash": facewash,
        "toner": evening_toner,
        "serum": evening_serum,
        "moisturizer": moisturizer,
    }

    return {"morning_routine": morning_routine, "evening_routine": evening_routine}

# Example call for testing
result = recommend_routines("Oily", "Acne-Free, Pore-Care, Brightening, Anti-Aging")
print(result)
# Out:
# {'morning_routine': {'facewash': [{'product_href': 'https://www.beautyhaul.com/product/detail/bubble-free-ph-balancing-cleanser', 'product_name': 'ACWELL Bubble Free PH Balancing Cleanser', 'product_type': 'face wash', 'brand': 'ACWELL ', 'notable_effects': 'acne-free, pore-care, brightening, anti-aging', 'skintype': 'oily', 'price': 'Rp 209.000', 'description': 'Mengangkat kotoran dan menghapus makeup dalam 1 step, sekaligus menjaga pH alami kulit. Membersihkan kulit dengan lembut tanpa rasa kering dan ketat. Dengan ekstrak Centella, Aloe, dan Witch Hazel yang melembapkan dan menenangkan, serta salicylic acid membantu mencegah jerawat. -No harmful chemicals, paraben, artificial dye, mineral oil, sulfates. -Sesuai untuk semua jenis kulit', 'picture_src': 'https://www.beautyhaul.com/assets/uploads/products/thumbs/800x800/ACWELL_BUBBLE_FREE_PH_BALANCING_CLEANSER.jpg'}], 'toner': [{'product_href': 'https://www.beautyhaul.com/product/detail/aquaseal-soothing-tonic', 'product_name': 'ACWELL Aquaseal Soothing Tonic ', 'product_type': 'toner', 'brand': 'ACWELL ', 'notable_effects': 'acne-free, pore-care, brightening, anti-aging', 'skintype': 'oily', 'price': 'Rp 290.000', 'description': 'Pre-essence yang diformulasikan dengan ekstrak Witch Hazel dan PURITOX yang menyegarkan dan menenangkan kulit sensitif. Anti-inflammatory, antioxidant, anti-bacterial dan menghidrasi, serta menjaga kulit tetap lembut dan sehat. No harmful chemicals, paraben, artificial dye, mineral oil, sulfates. Sesuai untuk kulit sensitif', 'picture_src': 'https://www.beautyhaul.com/assets/uploads/products/thumbs/800x800/ACWELL_AQUASEAL_SOOTHING_TONIC_%28rev%29.jpg'}], 'serum': [{'product_href': 'https://www.beautyhaul.com/product/detail/miraculous-refining-serum-anniversary-edition', 'product_name': 'AVOSKIN Miraculous Refining Serum Anniversary Edition ', 'product_type': 'serum', 'brand': 'AVOSKIN ', 'notable_effects': 'acne-free, pore-care, brightening, anti-aging', 'skintype': 'oily', 'price': 'Rp 239.000', 'description': 'Avoskin Miraculous Refining Serum berfungsi sebagai exfoliating serum yang mengandung AHA dan BHA sebagai agen eksfoliator. Kandungan 2% niacinamide, ceramide, Polyglutamic Acid yang dilengkapi dengan ekstrak alami Raspberry, Aloe Vera, Seaweed, dan Chamomile berfungsi melembapkan sehingga kulit tetap terjaga kelembapannya setelah proses eksfoliasi. Pada produk Miraculous Refining Serum Special Anniversary Edition ini, terdapat penambahan kandungan PGA dan Ceramide yang berfungsi untuk meningkatkan kelembapan ekstra pada kulit dan merawat skin barrier.', 'picture_src': 'https://www.beautyhaul.com/assets/uploads/products/thumbs/800x800/REFINING_SERUM.png'}], 'moisturizer': [{'product_href': 'https://www.beautyhaul.com/product/detail/100-organic-argan-oil', 'product_name': 'ARGAVELL 100% Organic Argan Oil', 'product_type': 'moisturizer', 'brand': 'ARGAVELL', 'notable_effects': 'acne-free, oil-control, anti-aging', 'skintype': 'normal, dry, oily, combination', 'price': 'Rp 130.000', 'description': 'Diekstrak secara alami dari biji buah Argan dari Morocco. Argan Oil memiliki kandungan unsaturated fatty acids & vitamin E yang 3x lipat lebih tinggi dari Olive Oil, yang sangat bagus untuk wajah, rambut & kulit! Benefit untuk wajah: pelembap kulit alami, mencegah Trans-Epidermal Water Loss; meningkatkan elastisitas kulit (Anti-Aging); kulit wajah kenyal cerah & glowing; mengurangi minyak berlebih pada wajah; kandungan antioxidant (vit E) yang mengurangi jerawat & breakout; menutrisi kulit dan melindungi kulit dari radikal bebas. Benefit untuk rambut: menutrisi kulit kepala & rambut dengan vit E; memicu pertumbuhan rambut & mengurangi kerontokan; melembapkan rambut menjadi halus & berkilau; rambut mudah diatur.', 'picture_src': 'https://www.beautyhaul.com/assets/uploads/products/thumbs/800x800/Argavell_Argan_Oil.png'}], 'sunscreen': [{'product_href': 'https://www.beautyhaul.com/product/detail/calm-my-acne-skinpair-sunscreen-moisturiser-spf35-pa', 'pro ...

# %%
print(recommend_routines("Oily",'Acne-Free, Pore-Care, Brightening, Anti-Aging'))
# Out:
# {'morning_routine': {'facewash': [], 'toner': [], 'serum': [], 'moisturizer': [], 'sunscreen': []}, 'evening_routine': {'facewash': [], 'toner': [], 'serum': [], 'moisturizer': []}}
